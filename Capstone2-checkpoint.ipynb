# %% [markdown]
# <h4>=====Importing required libraries===

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdt
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.api as sm
import re
import pandas_profiling 
from matplotlib.dates import DateFormatter
# %matplotlib inline

# %% [markdown]
# <h4> ==== Reading the data files. Here we are reading from 2 files-One with the stock data(stock_dt.xlsx) and covid data from Covid_numbers.xlsx =====

# %%
df1 = pd.read_excel('C:\Python_Projects\Datasets\stock_dT.xlsx')
df2 = pd.read_excel('C:\Python_Projects\Datasets\Covid_numbers.xlsx')

# %%
#pandas_profiling.ProfileReport(df1)

# %% [markdown]
# <h4>========EDA======== </h4>
# Some questions that can be answered:
#     <h5>Categorical :</h5>
# 1) Is it a balanced data-set or not, if not how the data being divided.
#
# 2) What percent of data divided between each categorical type ?
#
#    <h5> Quatitative </h5>
# 1) How data is distributed ?
#
# 2) What is the average value of the given quantitative column ?
#
# 3) Where is most of the data resides at ?
#
# 4) What is the range, minimum and maximum values present in the data-set?
#
# 5) What are the outliers in the data-set?

# %%
# Line plots showing the behavious of each stock attribute

mpl.rcParams['figure.figsize'] = (12,8)
sns.lineplot(x="Date",y="High",hue="company_name",data=df1)
plt.figure()
sns.lineplot(x="Date",y="Low",hue="company_name",data=df1)
plt.figure()
sns.lineplot(x="Date",y="Open",hue="company_name",data=df1)
plt.figure()
sns.lineplot(x="Date",y="Close",hue="company_name",data=df1)
plt.figure()
sns.lineplot(x="Date",y="Volume",hue="company_name",data=df1)

# %%
# Boxplots for all attributes compared by Company

sns.catplot(x="company_name", y="High", data=df1,kind = 'box', height=5, aspect=3);
plt.figure()
sns.catplot(x="company_name", y="Low", data=df1,kind = 'box',  height=5, aspect=3); 
plt.figure()
sns.catplot(x="company_name", y="Open", data=df1,kind = 'box',  height=5, aspect=3);
plt.figure()
sns.catplot(x="company_name", y="Close", data=df1,kind = 'box',  height=5, aspect=3); 
plt.figure()
sns.catplot(x="company_name", y="Volume", data=df1,kind = 'box',  height=5, aspect=3); 
plt.figure()

# %%
dfA=df1[df1['company_name'].isin(['APPLE'])]
dfU=df1[df1['company_name'].isin(['UNITED'])]
dfM=df1[df1['company_name'].isin(['MICROSOFT'])]
dfUb=df1[df1['company_name'].isin(['UBER'])]
dfG=df1[df1['company_name'].isin(['GOLD'])]
dfP=df1[df1['company_name'].isin(['PLG'])] #Platinum
dfMa=df1[df1['company_name'].isin(['MAR'])] #Marriot
dfD=df1[df1['company_name'].isin(['DAL'])] # Delta Airlines
dfJ=df1[df1['company_name'].isin(['JNJ'])] # Johnson&Johnson's
dfDi=df1[df1['company_name'].isin(['DIS'])] # Walt Disney
dfUv=df1[df1['company_name'].isin(['UVV'])] # Universal Studios
dfDk=df1[df1['company_name'].isin(['DKS'])] # Dicks Sporting Goods
dfMc=df1[df1['company_name'].isin(['M'])]  #Macy's
dfZ=df1[df1['company_name'].isin(['ZM'])] # Zomato
dfW=df1[df1['company_name'].isin(['WORK'])] # Slack
dfAm=df1[df1['company_name'].isin(['AMC'])] # AMC THeaters
dfSx=df1[df1['company_name'].isin(['SIX'])] # Six Flags Adventure Park


#dfA.describe()
#dfA.info()

#Plotting High's distribution graph
f, axes = plt.subplots(6, 3, figsize=(15, 8), sharex=True)
#sns.despine(left=True)

#mpl.rcParams['figure.figsize'] = (4,4)

sns.distplot(dfA["High"],  color="r", ax=axes[0, 0])
sns.distplot(dfU["High"], color="g", ax=axes[0, 1])
sns.distplot(dfM["High"], color="m", ax=axes[0, 2])
sns.distplot(dfUb["High"], color="y", ax=axes[1, 0])
sns.distplot(dfG["High"], color="c", ax=axes[1, 1])
sns.distplot(dfP["High"], color="r", ax=axes[1, 2])
sns.distplot(dfMa["High"], color="g", ax=axes[2, 0])
sns.distplot(dfD["High"],  color="m", ax=axes[2, 1])
sns.distplot(dfJ["High"], color="y", ax=axes[2, 2])
sns.distplot(dfDi["High"], color="g", ax=axes[3, 0])
sns.distplot(dfUv["High"], color="c", ax=axes[3, 1])
sns.distplot(dfDk["High"], color="y", ax=axes[3, 2])
sns.distplot(dfMc["High"],  color="m", ax=axes[4, 0])
sns.distplot(dfZ["High"], color="r", ax=axes[4, 1])
sns.distplot(dfW["High"], color="g", ax=axes[4, 2])
sns.distplot(dfAm["High"], color="y", ax=axes[5, 0])
sns.distplot(dfSx["High"], color="m", ax=axes[5, 1])

# %%
#Plotting Low's distribution graph
#mpl.rcParams['figure.figsize'] = (4,4)
#sns.distplot(dfAm["Low"])
#plt.show()

f, axes = plt.subplots(6, 3, figsize=(15, 8), sharex=True)
sns.distplot(dfA["Low"],  color="r", ax=axes[0, 0])
sns.distplot(dfU["Low"], color="g", ax=axes[0, 1])
sns.distplot(dfM["Low"], color="m", ax=axes[0, 2])
sns.distplot(dfUb["Low"], color="y", ax=axes[1, 0])
sns.distplot(dfG["Low"], color="c", ax=axes[1, 1])
sns.distplot(dfP["Low"], color="r", ax=axes[1, 2])
sns.distplot(dfMa["Low"], color="g", ax=axes[2, 0])
sns.distplot(dfD["Low"],  color="m", ax=axes[2, 1])
sns.distplot(dfJ["Low"], color="y", ax=axes[2, 2])
sns.distplot(dfDi["Low"], color="g", ax=axes[3, 0])
sns.distplot(dfUv["Low"], color="c", ax=axes[3, 1])
sns.distplot(dfDk["Low"], color="y", ax=axes[3, 2])
sns.distplot(dfMc["Low"],  color="m", ax=axes[4, 0])
sns.distplot(dfZ["Low"], color="r", ax=axes[4, 1])
sns.distplot(dfW["Low"], color="g", ax=axes[4, 2])
sns.distplot(dfAm["Low"], color="y", ax=axes[5, 0])
sns.distplot(dfSx["Low"], color="m", ax=axes[5, 1])

# %%
 #AAPL, UAL, MSFT, AMZN, UBER, GOLD, PLG, MAR, DAL, JNJ,DIS, UVV, DKS, M, ZM, WORK,AMC ,SIX
    
#f, axes = plt.subplots(6, 3, figsize=(15, 8), sharex=True)

mpl.rcParams['figure.figsize'] = (10,4)
sns.scatterplot(x="Date", y="Volume", data=dfA, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfU, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfM, color= 'b', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfUb, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfG, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfP, hue="company_name", color='r')
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfMa, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfD, color='y', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfJ, color= 'b', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfDi, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfUv, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfDk, hue="company_name", color='r')
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfMc, hue="company_name", color='r')
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfZ, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfW, color='y', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfAm, color= 'b', hue="company_name")
plt.show()
sns.scatterplot(x="Date", y="Volume", data=dfSx, color='g', hue="company_name")
plt.show()

# %%
mpl.rcParams['figure.figsize'] = (12,4)


sns.scatterplot(x="Volume", y="Low", data=dfA, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfU, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfM, color= 'b', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfUb, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfG, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfP, hue="company_name", color='r')
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfMa, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfD, color='y', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfJ, color= 'b', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfDi, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfUv, color='g', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfDk, hue="company_name", color='r')
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfMc, hue="company_name", color='r')
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfZ, hue="company_name", color='b')
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfW, color='y', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfAm, color= 'b', hue="company_name")
plt.show()
sns.scatterplot(x="Volume", y="Low", data=dfSx, color='g', hue="company_name")
plt.show()

# %%
dfAM.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count   755.000000   755.000000   755.000000   755.000000  7.550000e+02
# mean   1609.488994  1575.442173  1593.604291  1593.363562  4.581294e+06
# std     360.295977   351.186324   355.548984   355.890411  2.318305e+06
# min     940.789978   927.000000   940.000000   934.150024  8.813000e+05
# 25%    1399.280029  1346.974976  1368.445007  1374.719971  2.959550e+06
# 50%    1718.930054  1680.890015  1703.000000  1699.189941  3.925600e+06
# 75%    1858.720032  1825.149963  1842.005005  1846.489990  5.536550e+06
# max    2475.000000  2396.010010  2443.199951  2474.000000  1.656500e+07
#
#          Adj Close
# count   755.000000
# mean   1593.363562
# std     355.890411
# min     934.150024
# 25%    1374.719971
# 50%    1699.189941
# 75%    1846.489990
# max    2474.000000

# %%
df1.shape
df1['Date'] = pd.to_datetime(df1['Date'])
df1['company_name'] = df1['company_name'].astype("string")
df1.dropna(inplace = True)
df1.drop_duplicates(keep='first', inplace=True)
df1['return'] =((df1.groupby('company_name')['Close'].shift(1).fillna(0))/(df1['Close']))-1
#df1.info()
#df1.head(10)
#df1.shape

# %% [markdown]
# <h4>Observations from the EDA:</h4> </n>
#
#     1. 	Stock data taken from following industries:
#         a.	Technology (APPLE, Microsoft, Slack)
#         b.	Airlines (United, Delta)
#         c.	Travel and Tourism/Hospitality (UBER, Marriot)
#         d.	Entertainment (AMC, Six Flags, Disney, Universal Studios)
#         e.	Retails (Macys, Dicks)
#         f.	Hyperlocal Marketplace (Zomato)
#         g.	Pharma (Johnson and Johnson’s)
#
#     2.	All Stocks have shown a different behavior in month of March compared to previous years data.
#     3.	There is a lot of outliers present in volume for 2020 indicating more than normal buying-selling.
#     4.	Apple, United (Airlines), Gold, Platinum, Marriot(hotel), Delta (Airlines), Dicks (Retail),Zomato(Delivery), AMC(Entertainment), Six Flags(Entertainment) have outliers in their HIGH, LOW, OPEN and CLOSE stock values
#     5.	All of the stocks have outliers for volume. Highest being in Airlines, Technology and Retail
#     6.	In March 2020, average Highs, Lows values have gone down for AMC, Apple, DAL, DIS, DKS, MACY’s, Marriot, Six, United, Universal Studios and Uber.
#     7.	In March 2020, average High have gone up for GOLD, JNJ, Microsoft, Work, Zomato.
#     8.	In March 2020, average High have remained same for Platinum.
# <h5>Trends from before shows:</h5>
#
#     1.	AMC, Delta, United, Dicks, Macy’s, Disney, Six Flags, Marriot, Uber, Universal Studios are the most effected with their prices falling sharply from March through April and May.
#     2.	Apple had shown a slightly different trend, where in the past the stock prices seems to have gone up in March, in 2020 they have fallen in February, March and April moving back up in May.However values still remains high compared to last 3 years.
#     3.	Gold , Microsoft and Johnson’s is at highest high and keeps rising.
#     4.	Zomato and Slack have seen an increase in demand in the pandemic and have shown a tremendous increase in price.
#
# <h5>In terms of Volume traded:</h5>
#
#     1.	March and April has shown large volume of stocks being bought or sold for all the stocks.
#     2.	Volume has lowered for almost all in April and May
#     3.	Microsoft and Apple has largest volume of stock traded in March
#     4.	Overall There has been a large volume of trade happening in march seen with sharp drop in April.
#     5.	United airlines shows exception with large volume of trade starting in March and the volume kept increasing in April and May.
#     6.	News shows that S&P500, an index of stock market fell to its lowest on March 23rd due to uncertainty caused by Covid19 effect.This might have caused people to panic buy/sell stocks in March.

# %%
#to_drop = ['pending','hash','dateChecked','hospitalized','total','posNeg','fips']
#df2.drop(to_drop,axis=1, inplace=True)
df2['Date'] = pd.to_datetime(df2['Date'])
df2['state'] = df2['state'].astype("string")
df2.info()
df2.head()
#df2.count()
#df2.isnull().sum()
#df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      167 non-null    datetime64[ns]
#  1   state                     167 non-null    string
#  2   positive                  167 non-null    int64
#  3   negative                  164 non-null    float64
#  4   hospitalizedCurrently     53 non-null     float64
#  5   hospitalizedCumulative    86 non-null     float64
#  6   inIcuCurrently            0 non-null      float64
#  7   inIcuCumulative           28 non-null     float64
#  8   onVentilatorCurrently     37 non-null     float64
#  9   onVentilatorCumulative    46 non-null     float64
#  10  recovered                 61 non-null     float64
#  11  dataQualityGrade          117 non-null    object
#  12  lastUpdateEt              150 non-null    datetime64[ns]
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      167 non-null    int64
#  1   state                     167 non-null    object
#  2   positive                  167 non-null    int64
#  3   negative                  164 non-null    float64
#  4   pending                   29 non-null     float64
#  5   hospitalizedCurrently     53 non-null     float64
#  6   hospitalizedCumulative    86 non-null     float64
#  7   inIcuCurrently            0 non-null      float64
#  8   inIcuCumulative           28 non-null     float64
#  9   onVentilatorCurrently     37 non-null     float64
#  10  onVentilatorCumulative    46 non-null     float64
#  11  recovered                 61 non-null     float64
#  12  dataQualityGrade          117 non-null    object
# ...

# %%
# Boxplots for all attributes compared by Company

sns.catplot(x="state", y="positive", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="negative", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="hospitalizedCurrently", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="hospitalizedCumulative", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="inIcuCurrently", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="inIcuCumulative", data=df2,kind = 'box',height=5, aspect=3);

# %%
sns.catplot(x="state", y="onVentilatorCurrently", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="onVentilatorCumulative", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="recovered", data=df2,kind = 'box',height=5, aspect=3);
sns.catplot(x="state", y="totalTestResults", data=df2,kind = 'box',height=5, aspect=3);

# %%
# Histograms for all compared by state
df2.hist(by='state',column = 'positive',figsize=(12,8))
df2.hist(by='state',column = 'negative',figsize=(12,8),color='#86bf91')
df2.hist(by='state',column = 'hospitalizedCurrently',figsize=(12,8))
df2.hist(by='state',column = 'hospitalizedCumulative',figsize=(12,8),color='#86bf91')
df2.hist(by='state',column = 'inIcuCurrently',figsize=(12,8))
plt.show()

# %%
# Bar plot for all attributes compared by Company
sns.catplot(x="state", y="positive", data=df2,kind = 'bar',height=5, aspect=3);
sns.catplot(x="state", y="negative", data=df2,kind = 'bar',height=5, aspect=3); 
sns.catplot(x="state", y="hospitalizedCurrently", data=df2,kind = 'bar',height=5, aspect=3);
sns.catplot(x="state", y="hospitalizedCumulative", data=df2,kind = 'bar',height=5, aspect=3); 
sns.catplot(x="state", y="inIcuCurrently", data=df2,kind = 'bar',height=5, aspect=3); 
sns.catplot(x="state", y="inIcuCumulative", data=df2,kind = 'bar',height=5, aspect=3);
